# %% [markdown]
# # Relation
# Gráficos de tipo relación, Seaborn maneja también el Scatterplot, entre otros.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %% [markdown]
# ## Scatterplot

# %%
#Grafico de dispersión
sns.scatterplot(data=tips,x='total_bill',y='tip')
plt.show()

# %% [markdown]
# Vamos a analizar la relación que existe entre la cuenta y el total de las propinas. Se puede ver un comportamiento de relación - > Entre mas crece la cuenta, tiende a crecer la propina, también hay casos atípicos

# %% [markdown]
# ### Segmentando por día

# %%
#Grafico de dispersión
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day')
plt.show()

# %% [markdown]
# Podemos ver que por color se hace la segmentación y por ciertos días hay un consumo mayor en la cuenta y a su vez una mayor propina.

# %% [markdown]
# ### Estilo dependiente de 'time'

# %%
#Grafico de dispersión
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day',style='time')
plt.show()

# %% [markdown]
# Aquí hay otro tipo de segmentación en el que gráficamente se puedde distinguir entre `lunch` y `dinner`, por medio de un marcador diferente. Entonces como se puede apreciar, parece que para `dinner` hay tanto un consumo mayor en `total_bill` y `tip`

# %% [markdown]
# ### Tamaño de marcador relacionado a size(número de comensales)

# %%
#Grafico de dispersión
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size')
plt.show()

# %% [markdown]
# La leyenda anterior me molesta la gráfica así que vamos a moverla.

# %%
#Grafico de dispersión
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size')
plt.legend(loc='center',bbox_to_anchor=(1.12,0.5))
plt.show()

# %% [markdown]
# Así mi leyenda ya no me estorba y puedo realizar un analisis correctamente.

# %% [markdown]
# ### Definiendo markers

# %%
#Grafico de dispersión
marker = {'Lunch':'D','Dinner':'s'}
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',markers=marker)
plt.legend(loc='center',bbox_to_anchor=(1.12,0.5))
plt.show()

# %% [markdown]
# ### Ajustando tamaño

# %%
#Grafico de dispersión
marker = {'Lunch':'D','Dinner':'s'}
plt.figure(figsize=(8,8))
sns.scatterplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',markers=marker)
plt.legend(loc='center',bbox_to_anchor=(1.12,0.5))
plt.show()

# %% [markdown]
# ## Lineplot

# %%
#Grafico lineplot
sns.lineplot(data=tips,x='total_bill',y='tip')
plt.show()

# %%
#Grafico lineplot
sns.lineplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',markers=marker)
plt.show()

# %%
#Grafico lineplot
marker = {'Lunch':'D','Dinner':'s'}
plt.figure(figsize=(8,8))
sns.lineplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',markers=marker)
plt.legend(loc='center',bbox_to_anchor=(1.12,0.5))
plt.show()

# %% [markdown]
# ## Relplot

# %%
#Grafico relplot
sns.relplot(data=tips,x='total_bill',y='tip')
plt.show()

# %%
#Grafico replot
sns.relplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',markers=marker)
plt.show()

# %% [markdown]
# ### Usando Kind

# %%
#Grafico replot
sns.relplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',markers=marker,kind='line')
plt.show()

# %% [markdown]
# ### Usando col = 'day' & kind = 'scatter'

# %%
#Grafico replot
sns.relplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',markers=marker,col='day',kind='scatter')
plt.show()

# %%
#Grafico replot
sns.relplot(data=tips,x='total_bill',y='tip',hue='day',style='time',size='size',col='time',kind='scatter')
plt.show()

# %% [markdown]
# ## Extra:
# Aporte de Carlos Felipe Saldarriaga Bejarano<br>
# También podemos usar pairplot, te permite ver comparativas de pares de variables y analizar su comportamiento en un solo gráfico.<br>
# ```python
# sns.pairplot(data=tips,hue='day')
# plt.show()
# ```

# %%
sns.pairplot(data=tips,hue='day')
plt.show()

# %% [markdown]
# Aporte de Carlos Castillo<br>
# No se porque hasta ahora no se menciona pero hay un parametro llamado "ax" para poder usar seaborn en subplots.
#
# ![AX](images/rel_axe.jpg)

# %% [markdown]
# # Referencias:
# - [Relplot](https://seaborn.pydata.org/generated/seaborn.relplot.html)
